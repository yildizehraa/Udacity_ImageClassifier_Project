# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Imports here
import numpy as np
import seaborn as sb
import torch
from torch import nn
from torch import tensor
from torch import optim
import matplotlib.pyplot as plt
import time
import json
import PIL
import torchvision
import torch.nn.functional as Fl
from torch.autograd import Variable
from torchvision import datasets, transforms,models 
import argparse
from collections import OrderedDict
from PIL import Image

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets
data_transforms = {
    'train' : transforms.Compose([
        transforms.RandomResizedCrop(size=224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.454, 0.406],
                            [0.229, 0.224, 0.225])
    ]),
    'valid' : transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.454, 0.406],
                            [0.229, 0.224, 0.225])
    ]),
    'test' : transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.454, 0.406],
                             [0.229, 0.224, 0.225])
    ])
                }

# TODO: Load the datasets with ImageFolder
image_datasets = {
    'train' : datasets.ImageFolder(train_dir, transform=data_transforms['train']),
    'valid' : datasets.ImageFolder(valid_dir, transform=data_transforms['valid']),
    'test' : datasets.ImageFolder(test_dir, transform=data_transforms['test'])
}


trainLoader = torch.utils.data.DataLoader(image_datasets['train'], batch_size = 64, shuffle = True)
validationLoader = torch.utils.data.DataLoader(image_datasets['valid'], batch_size = 32, shuffle = True)
testLoader = torch.utils.data.DataLoader(image_datasets['test'], batch_size = 32, shuffle = True)


train_data_size = len(image_datasets['train'])
validation_data_size = len(image_datasets['valid'])
test_data_size =  len(image_datasets['test'])

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# **Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
# TODO: Build and train your network

model = models.vgg16(pretrained=True)

for pr in model.parameters():
    pr.required_grad = False

# %%
   
### Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
classifier = nn.Sequential(OrderedDict([
            ('inputs', nn.Linear(25088, 120)),
            ('rl1', nn.ReLU()),
            ('dropout', nn.Dropout(0.5)),
            ('hiddenLayer_1', nn.Linear(120, 90)),
            ('rl2', nn.ReLU()),
            ('hiddenLayer_2', nn.Linear(90,70)),
            ('rl3', nn.ReLU()),
            ('hiddenLayer_3', nn.Linear(70, 102)),
            ('output', nn.LogSoftmax(dim=1))]))

model.classifier = classifier
    
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.classifier.parameters(), lr=0.001)

model.cuda()
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (inputs): Linear(in_features=25088, out_features=120, bias=True)
#     (rl1): ReLU()
#     (dropout): Dropout(p=0.5)
#     (hiddenLayer_1): Linear(in_features=120, out_features=90, bias=True)
#     (rl2): ReLU()
#     (hiddenLayer_2): Linear(in_features=90, out_features=70, bias=True)
#     (rl3): ReLU()
#     (hiddenLayer_3): Linear(in_features=70, out_features=102, bias=True)
#     (output): LogSoftmax()
#   )
# )

# %%
#Train the classifier layers using backpropagation using the pre-trained network to get the features
#Track the loss and accuracy on the validation set to determine the best hyperparameters

epochs = 3
history = []

print(' *** Training Started *** ')

for epoch in range(epochs):
    model.train()
    print("Epoch: {}/{}".format(epoch+1, epochs))
    trainLoss = 0.0
    trainAcc = 0.0
    valid_loss = 0.0
    valid_acc = 0.0
    for i, (inputs, labels) in enumerate(trainLoader):
        inputs = inputs.to('cuda')
        labels = labels.to('cuda')
        
        optimizer.zero_grad()
        
        outputs = model.forward(inputs)
    
        loss = criterion(outputs, labels)
        loss.backward()
        
        optimizer.step()
        
        trainLoss += loss.item() * inputs.size(0)
                
        #accuracy
        ret, ps = torch.max(outputs.data, 1)
        total = ps.eq(labels.data.view_as(ps))
        
        # compute mean
        accuracy = torch.mean(total.type(torch.FloatTensor))
        
        trainAcc += accuracy.item() * inputs.size(0)
               
        print("Iteration : {:03d}, Loss on trainig: {:.4f}, Accuracy: {:.4f}".format(i, loss.item(), accuracy.item()))
        
    with torch.no_grad():
        model.eval()
        for j, (inputs, labels) in enumerate(validationLoader):
            inputs = inputs.to('cuda')
            labels = labels.to('cuda')
            outputs = model(inputs)

            loss = criterion(outputs, labels)
            valid_loss += loss.item() * inputs.size(0)

            ret, predictions = torch.max(outputs.data, 1)
            correct_prediction_counts = predictions.eq(labels.data.view_as(predictions))

            acc = torch.mean(correct_prediction_counts.type(torch.FloatTensor))
            valid_acc +=acc.item() * inputs.size(0)

        avg_train_loss = trainLoss/train_data_size
        avg_train_acc = trainAcc/train_data_size

        avg_valid_loss = valid_loss/validation_data_size
        avg_valid_acc = valid_acc/validation_data_size

     #   history.append([avg_train_loss, avg_valid_loss, avg_train_acc, avg_valid_acc])


        print(f'Epoch : {epoch}, Training: Loss: f{avg_train_loss}, Accuracy: {avg_train_acc*100}%, \n\t\tValidation : Loss : {avg_valid_loss}, Accuracy: {avg_valid_acc*100}%')


        
print(' *** Training Ended *** ')
# Out:
#  *** Training Started ***
# Epoch: 1/3
# Iteration : 000, Loss on trainig: 3.4790, Accuracy: 0.2344
# Iteration : 001, Loss on trainig: 3.2352, Accuracy: 0.2500
# Iteration : 002, Loss on trainig: 3.3365, Accuracy: 0.1719
# Iteration : 003, Loss on trainig: 3.4449, Accuracy: 0.1406
# Iteration : 004, Loss on trainig: 3.2027, Accuracy: 0.3438
# Iteration : 005, Loss on trainig: 3.2980, Accuracy: 0.2188
# Iteration : 006, Loss on trainig: 3.4032, Accuracy: 0.2031
# Iteration : 007, Loss on trainig: 3.5606, Accuracy: 0.2031
# Iteration : 008, Loss on trainig: 3.4590, Accuracy: 0.1406
# Iteration : 009, Loss on trainig: 3.4616, Accuracy: 0.1719
# Iteration : 010, Loss on trainig: 3.0328, Accuracy: 0.2500
# Iteration : 011, Loss on trainig: 2.8188, Accuracy: 0.3125
# Iteration : 012, Loss on trainig: 3.3326, Accuracy: 0.1719
# Iteration : 013, Loss on trainig: 2.9187, Accuracy: 0.3125
# Iteration : 014, Loss on trainig: 3.1408, Accuracy: 0.2969
# Iteration : 015, Loss on trainig: 2.8136, Accuracy: 0.3281
# Iteration : 016, Loss on trainig: 2.6781, Accuracy: 0.3281
# Iteration : 017, Loss on trainig: 3.0969, Accuracy: 0.2500
# Iteration : 018, Loss on trainig: 3.3856, Accuracy: 0.1875
# Iteration : 019, Loss on trainig: 2.9169, Accuracy: 0.2969
# Iteration : 020, Loss on trainig: 2.7005, Accuracy: 0.3438
# Iteration : 021, Loss on trainig: 2.6519, Accuracy: 0.4219
# Iteration : 022, Loss on trainig: 3.0126, Accuracy: 0.3438
# Iteration : 023, Loss on trainig: 3.0774, Accuracy: 0.2188
# Iteration : 024, Loss on trainig: 3.1808, Accuracy: 0.2031
# Iteration : 025, Loss on trainig: 3.3397, Accuracy: 0.1250
# Iteration : 026, Loss on trainig: 3.0932, Accuracy: 0.2500
# Iteration : 027, Loss on trainig: 3.0284, Accuracy: 0.3125
# Iteration : 028, Loss on trainig: 2.5668, Accuracy: 0.3281
# Iteration : 029, Loss on trainig: 2.7239, Accuracy: 0.2656
# Iteration : 030, Loss on trainig: 3.0075, Accuracy: 0.2344
# Iteration : 031, Loss on trainig: 3.0994, Accuracy: 0.2344
# Iteration : 032, Loss on trainig: 2.9146, Accuracy: 0.2656
# Iteration : 033, Loss on trainig: 3.0996, Accuracy: 0.2344
# Iteration : 034, Loss on trainig: 2.6780, Accuracy: 0.3438
# Iteration : 035, Loss on trainig: 2.7625, Accuracy: 0.3125
# Iteration : 036, Loss on trainig: 2.8372, Accuracy: 0.2656
# Iteration : 037, Loss on trainig: 2.7284, Accuracy: 0.2500
# Iteration : 038, Loss on trainig: 3.0287, Accuracy: 0.2188
# Iteration : 039, Loss on trainig: 2.8314, Accuracy: 0.2344
# Iteration : 040, Loss on trainig: 2.9278, Accuracy: 0.2656
# Iteration : 041, Loss on trainig: 2.6806, Accuracy: 0.2812
# Iteration : 042, Loss on trainig: 3.2090, Accuracy: 0.2656
# Iteration : 043, Loss on trainig: 2.9163, Accuracy: 0.2969
# Iteration : 044, Loss on trainig: 2.9100, Accuracy: 0.2344
# Iteration : 045, Loss on trainig: 2.6434, Accuracy: 0.3594
# Iteration : 046, Loss on trainig: 2.8551, Accuracy: 0.3281
# Iteration : 047, Loss on trainig: 2.8952, Accuracy: 0.2656
# Iteration : 048, Loss on trainig: 2.7240, Accuracy: 0.3125
# Iteration : 049, Loss on trainig: 2.7618, Accuracy: 0.3125
# Iteration : 050, Loss on trainig: 2.5766, Accuracy: 0.3281
# Iteration : 051, Loss on trainig: 3.0789, Accuracy: 0.2656
# Iteration : 052, Loss on trainig: 2.3963, Accuracy: 0.4219
# Iteration : 053, Loss on trainig: 2.9684, Accuracy: 0.2500
# Iteration : 054, Loss on trainig: 2.9110, Accuracy: 0.3125
# Iteration : 055, Loss on trainig: 2.7892, Accuracy: 0.3281
# Iteration : 056, Loss on trainig: 3.2284, Accuracy: 0.1719
# Iteration : 057, Loss on trainig: 2.7961, Accuracy: 0.3281
# Iteration : 058, Loss on trainig: 2.7914, Accuracy: 0.3750
# Iteration : 059, Loss on trainig: 2.3337, Accuracy: 0.4219
# Iteration : 060, Loss on trainig: 2.8377, Accuracy: 0.3438
# Iteration : 061, Loss on trainig: 3.1248, Accuracy: 0.2188
# Iteration : 062, Loss on trainig: 2.8049, Accuracy: 0.3438
# Iteration : 063, Loss on trainig: 3.0901, Accuracy: 0.3125
# Iteration : 064, Loss on trainig: 2.4288, Accuracy: 0.4219
# Iteration : 065, Loss on trainig: 2.6108, Accuracy: 0.4531
# Iteration : 066, Loss on trainig: 2.8142, Accuracy: 0.2656
# Iteration : 067, Loss on trainig: 2.7822, Accuracy: 0.3281
# Iteration : 068, Loss on trainig: 3.2593, Accuracy: 0.2656
# Iteration : 069, Loss on trainig: 2.9397, Accuracy: 0.2812
# Iteration : 070, Loss on trainig: 2.7696, Accuracy: 0.3281
# Iteration : 071, Loss on trainig: 2.4223, Accuracy: 0.3125
# Iteration : 072, Loss on trainig: 3.1161, Accuracy: 0.2344
# Iteration : 073, Loss on trainig: 2.8134, Accuracy: 0.2344
# Iteration : 074, Loss on trainig: 2.8257, Accuracy: 0.3125
# Iteration : 075, Loss on trainig: 2.2832, Accuracy: 0.4062
# Iteration : 076, Loss on trainig: 2.8465, Accuracy: 0.2969
# Iteration : 077, Loss on trainig: 3.0144, Accuracy: 0.2969
# Iteration : 078, Loss on trainig: 2.7913, Accuracy: 0.2656
# Iteration : 079, Loss on trainig: 2.6004, Accuracy: 0.3281
# Iteration : 080, Loss on trainig: 2.6160, Accuracy: 0.3281
# Iteration : 081, Loss on trainig: 2.4067, Accuracy: 0.3594
# Iteration : 082, Loss on trainig: 2.2470, Accuracy: 0.3750
# Iteration : 083, Loss on trainig: 2.8782, Accuracy: 0.2188
# Iteration : 084, Loss on trainig: 3.0837, Accuracy: 0.3125
# Iteration : 085, Loss on trainig: 2.7283, Accuracy: 0.2969
# Iteration : 086, Loss on trainig: 2.7379, Accuracy: 0.2812
# Iteration : 087, Loss on trainig: 2.5098, Accuracy: 0.3438
# Iteration : 088, Loss on trainig: 2.4483, Accuracy: 0.3750
# Iteration : 089, Loss on trainig: 2.4157, Accuracy: 0.3750
# Iteration : 090, Loss on trainig: 2.6480, Accuracy: 0.3125
# Iteration : 091, Loss on trainig: 2.7098, Accuracy: 0.3438
# Iteration : 092, Loss on trainig: 2.5715, Accuracy: 0.3438
# Iteration : 093, Loss on trainig: 2.6503, Accuracy: 0.3906
# Iteration : 094, Loss on trainig: 2.9063, Accuracy: 0.2344
# Iteration : 095, Loss on trainig: 2.6198, Accuracy: 0.3438
# Iteration : 096, Loss on trainig: 2.9141, Accuracy: 0.3594
# Iteration : 097, Loss on trainig: 2.4328, Accuracy: 0.4062
# Iteration : 098, Loss on trainig: 2.6399, Accuracy: 0.3594
# Iteration : 099, Loss on trainig: 2.4485, Accuracy: 0.3594
# Iteration : 100, Loss on trainig: 2.7355, Accuracy: 0.2656
# Iteration : 101, Loss on trainig: 2.4492, Accuracy: 0.3594
# Iteration : 102, Loss on trainig: 2.6160, Accuracy: 0.4167
# Epoch : 0, Training: Loss: f2.869106837972471, Accuracy: 29.39560439196553%,
# 		Validation : Loss : 1.7711132569534562, Accuracy: 54.2787286136436%
# Epoch: 2/3
# Iteration : 000, Loss on trainig: 2.4836, Accuracy: 0.3906
# Iteration : 001, Loss on trainig: 2.6378, Accuracy: 0.2656
# Iteration : 002, Loss on trainig: 2.4243, Accuracy: 0.3594
# Iteration : 003, Loss on trainig: 2.4560, Accuracy: 0.3750
# Iteration : 004, Loss on trainig: 2.6534, Accuracy: 0.2969
# Iteration : 005, Loss on trainig: 2.3427, Accuracy: 0.3281
# Iteration : 006, Loss on trainig: 2.5892, Accuracy: 0.2969
# Iteration : 007, Loss on trainig: 2.3696, Accuracy: 0.4062
# Iteration : 008, Loss on trainig: 2.3557, Accuracy: 0.4375
# Iteration : 009, Loss on trainig: 2.3379, Accuracy: 0.4375
# Iteration : 010, Loss on trainig: 2.6613, Accuracy: 0.2969
# Iteration : 011, Loss on trainig: 2.4289, Accuracy: 0.3438
# Iteration : 012, Loss on trainig: 2.6503, Accuracy: 0.3125
# Iteration : 013, Loss on trainig: 2.3603, Accuracy: 0.2969
# Iteration : 014, Loss on trainig: 2.3727, Accuracy: 0.3906
# Iteration : 015, Loss on trainig: 2.0943, Accuracy: 0.4531
# Iteration : 016, Loss on trainig: 2.4443, Accuracy: 0.3750
# Iteration : 017, Loss on trainig: 2.1375, Accuracy: 0.5000
# Iteration : 018, Loss on trainig: 2.8163, Accuracy: 0.3594
# Iteration : 019, Loss on trainig: 2.3473, Accuracy: 0.3906
# Iteration : 020, Loss on trainig: 1.8523, Accuracy: 0.4688
# Iteration : 021, Loss on trainig: 2.3153, Accuracy: 0.4531
# Iteration : 022, Loss on trainig: 2.7324, Accuracy: 0.3750
# Iteration : 023, Loss on trainig: 2.2917, Accuracy: 0.4844
# Iteration : 024, Loss on trainig: 2.3916, Accuracy: 0.3906
# Iteration : 025, Loss on trainig: 2.5455, Accuracy: 0.2969
# Iteration : 026, Loss on trainig: 2.2888, Accuracy: 0.3906
# Iteration : 027, Loss on trainig: 2.0075, Accuracy: 0.4688
# Iteration : 028, Loss on trainig: 2.4773, Accuracy: 0.3281
# Iteration : 029, Loss on trainig: 2.5797, Accuracy: 0.2969
# Iteration : 030, Loss on trainig: 2.3420, Accuracy: 0.3750
# Iteration : 031, Loss on trainig: 2.0212, Accuracy: 0.4688
# Iteration : 032, Loss on trainig: 2.2105, Accuracy: 0.4531
# Iteration : 033, Loss on trainig: 2.6702, Accuracy: 0.3438
# Iteration : 034, Loss on trainig: 2.0571, Accuracy: 0.4531
# Iteration : 035, Loss on trainig: 2.6063, Accuracy: 0.2812
# Iteration : 036, Loss on trainig: 2.8266, Accuracy: 0.2500
# Iteration : 037, Loss on trainig: 2.5836, Accuracy: 0.3281
# Iteration : 038, Loss on trainig: 2.5050, Accuracy: 0.2969
# Iteration : 039, Loss on trainig: 2.2510, Accuracy: 0.3438
# Iteration : 040, Loss on trainig: 2.4522, Accuracy: 0.3438
# Iteration : 041, Loss on trainig: 2.1543, Accuracy: 0.4062
# Iteration : 042, Loss on trainig: 2.5404, Accuracy: 0.3750
# Iteration : 043, Loss on trainig: 1.8637, Accuracy: 0.5781
# Iteration : 044, Loss on trainig: 2.4408, Accuracy: 0.3281
# Iteration : 045, Loss on trainig: 2.4148, Accuracy: 0.4062
# Iteration : 046, Loss on trainig: 2.1066, Accuracy: 0.4062
# Iteration : 047, Loss on trainig: 2.1269, Accuracy: 0.4375
# Iteration : 048, Loss on trainig: 2.4726, Accuracy: 0.2969
# Iteration : 049, Loss on trainig: 2.2059, Accuracy: 0.3594
# Iteration : 050, Loss on trainig: 2.3608, Accuracy: 0.4062
# Iteration : 051, Loss on trainig: 2.3006, Accuracy: 0.3594
# Iteration : 052, Loss on trainig: 2.4420, Accuracy: 0.3906
# Iteration : 053, Loss on trainig: 2.2805, Accuracy: 0.4688
# Iteration : 054, Loss on trainig: 2.3331, Accuracy: 0.4062
# Iteration : 055, Loss on trainig: 2.4810, Accuracy: 0.3438
# Iteration : 056, Loss on trainig: 2.6878, Accuracy: 0.2656
# Iteration : 057, Loss on trainig: 2.5090, Accuracy: 0.3750
# Iteration : 058, Loss on trainig: 2.0502, Accuracy: 0.5312
# Iteration : 059, Loss on trainig: 2.4867, Accuracy: 0.3125
# Iteration : 060, Loss on trainig: 2.0947, Accuracy: 0.4844
# Iteration : 061, Loss on trainig: 2.1915, Accuracy: 0.4375
# Iteration : 062, Loss on trainig: 2.2385, Accuracy: 0.3594
# Iteration : 063, Loss on trainig: 2.5689, Accuracy: 0.3125
# Iteration : 064, Loss on trainig: 2.7968, Accuracy: 0.3438
# Iteration : 065, Loss on trainig: 2.2262, Accuracy: 0.3906
# Iteration : 066, Loss on trainig: 2.6975, Accuracy: 0.3438
# Iteration : 067, Loss on trainig: 2.2299, Accuracy: 0.4688
# Iteration : 068, Loss on trainig: 2.0506, Accuracy: 0.4531
# Iteration : 069, Loss on trainig: 2.2924, Accuracy: 0.3281
# Iteration : 070, Loss on trainig: 2.1510, Accuracy: 0.4375
# Iteration : 071, Loss on trainig: 2.1407, Accuracy: 0.4688
# Iteration : 072, Loss on trainig: 2.1591, Accuracy: 0.3906
# Iteration : 073, Loss on trainig: 2.2477, Accuracy: 0.4062
# Iteration : 074, Loss on trainig: 2.1394, Accuracy: 0.4375
# Iteration : 075, Loss on trainig: 2.7891, Accuracy: 0.3125
# Iteration : 076, Loss on trainig: 2.0985, Accuracy: 0.5000
# Iteration : 077, Loss on trainig: 2.0691, Accuracy: 0.4219
# Iteration : 078, Loss on trainig: 2.3568, Accuracy: 0.3594
# Iteration : 079, Loss on trainig: 2.4487, Accuracy: 0.4062
# Iteration : 080, Loss on trainig: 2.6317, Accuracy: 0.2656
# Iteration : 081, Loss on trainig: 2.1737, Accuracy: 0.4219
# Iteration : 082, Loss on trainig: 2.2012, Accuracy: 0.4219
# Iteration : 083, Loss on trainig: 2.2914, Accuracy: 0.3750
# Iteration : 084, Loss on trainig: 2.0766, Accuracy: 0.4688
# Iteration : 085, Loss on trainig: 2.7296, Accuracy: 0.2969
# Iteration : 086, Loss on trainig: 2.0142, Accuracy: 0.4844
# Iteration : 087, Loss on trainig: 2.3787, Accuracy: 0.4219
# Iteration : 088, Loss on trainig: 2.3395, Accuracy: 0.3906
# Iteration : 089, Loss on trainig: 2.7530, Accuracy: 0.3281
# Iteration : 090, Loss on trainig: 2.6687, Accuracy: 0.4062
# Iteration : 091, Loss on trainig: 2.3598, Accuracy: 0.4531
# Iteration : 092, Loss on trainig: 2.2047, Accuracy: 0.3594
# Iteration : 093, Loss on trainig: 2.6012, Accuracy: 0.3438
# Iteration : 094, Loss on trainig: 2.4345, Accuracy: 0.3906
# Iteration : 095, Loss on trainig: 2.0407, Accuracy: 0.4375
# Iteration : 096, Loss on trainig: 2.0243, Accuracy: 0.4531
# Iteration : 097, Loss on trainig: 2.2752, Accuracy: 0.3750
# Iteration : 098, Loss on trainig: 2.1704, Accuracy: 0.3906
# Iteration : 099, Loss on trainig: 2.4173, Accuracy: 0.3281
# Iteration : 100, Loss on trainig: 2.1054, Accuracy: 0.4688
# Iteration : 101, Loss on trainig: 2.3789, Accuracy: 0.3906
# Iteration : 102, Loss on trainig: 2.4364, Accuracy: 0.3333
# Epoch : 1, Training: Loss: f2.358004416592683, Accuracy: 38.59890110253997%,
# 		Validation : Loss : 1.3613313812498358, Accuracy: 65.15892420537898%
# Epoch: 3/3
# Iteration : 000, Loss on trainig: 2.0589, Accuracy: 0.4531
# Iteration : 001, Loss on trainig: 2.3335, Accuracy: 0.4062
# Iteration : 002, Loss on trainig: 2.7039, Accuracy: 0.2969
# Iteration : 003, Loss on trainig: 1.5408, Accuracy: 0.5469
# Iteration : 004, Loss on trainig: 2.2039, Accuracy: 0.3594
# Iteration : 005, Loss on trainig: 2.2715, Accuracy: 0.3906
# Iteration : 006, Loss on trainig: 2.5923, Accuracy: 0.3438
# Iteration : 007, Loss on trainig: 2.3003, Accuracy: 0.3750
# Iteration : 008, Loss on trainig: 2.1433, Accuracy: 0.4062
# Iteration : 009, Loss on trainig: 2.2803, Accuracy: 0.3594
# Iteration : 010, Loss on trainig: 2.1434, Accuracy: 0.4375
# Iteration : 011, Loss on trainig: 2.0085, Accuracy: 0.3750
# Iteration : 012, Loss on trainig: 2.4265, Accuracy: 0.3281
# Iteration : 013, Loss on trainig: 2.0360, Accuracy: 0.3750
# Iteration : 014, Loss on trainig: 2.2274, Accuracy: 0.3750
# Iteration : 015, Loss on trainig: 2.1865, Accuracy: 0.4219
# Iteration : 016, Loss on trainig: 2.1330, Accuracy: 0.4531
# Iteration : 017, Loss on trainig: 2.2492, Accuracy: 0.5000
# Iteration : 018, Loss on trainig: 1.7935, Accuracy: 0.5469
# Iteration : 019, Loss on trainig: 2.2283, Accuracy: 0.4375
# Iteration : 020, Loss on trainig: 2.0191, Accuracy: 0.4531
# Iteration : 021, Loss on trainig: 2.1169, Accuracy: 0.3906
# Iteration : 022, Loss on trainig: 1.9316, Accuracy: 0.5000
# Iteration : 023, Loss on trainig: 1.8922, Accuracy: 0.5156
# Iteration : 024, Loss on trainig: 1.9398, Accuracy: 0.3906
# Iteration : 025, Loss on trainig: 2.5535, Accuracy: 0.3125
# Iteration : 026, Loss on trainig: 2.0853, Accuracy: 0.4375
# Iteration : 027, Loss on trainig: 2.2047, Accuracy: 0.3594
# Iteration : 028, Loss on trainig: 2.0330, Accuracy: 0.4844
# Iteration : 029, Loss on trainig: 2.4998, Accuracy: 0.3594
# Iteration : 030, Loss on trainig: 2.5147, Accuracy: 0.3281
# Iteration : 031, Loss on trainig: 2.1238, Accuracy: 0.4531
# Iteration : 032, Loss on trainig: 1.8922, Accuracy: 0.4062
# Iteration : 033, Loss on trainig: 2.0731, Accuracy: 0.4844
# Iteration : 034, Loss on trainig: 2.3828, Accuracy: 0.3594
# Iteration : 035, Loss on trainig: 2.1890, Accuracy: 0.3750
# Iteration : 036, Loss on trainig: 1.9718, Accuracy: 0.5156
# Iteration : 037, Loss on trainig: 2.0174, Accuracy: 0.4375
# Iteration : 038, Loss on trainig: 2.2068, Accuracy: 0.3750
# Iteration : 039, Loss on trainig: 2.1629, Accuracy: 0.3594
# Iteration : 040, Loss on trainig: 1.9573, Accuracy: 0.4688
# Iteration : 041, Loss on trainig: 2.5878, Accuracy: 0.3281
# Iteration : 042, Loss on trainig: 2.0566, Accuracy: 0.4375
# Iteration : 043, Loss on trainig: 2.2734, Accuracy: 0.3750
# Iteration : 044, Loss on trainig: 2.0277, Accuracy: 0.4531
# Iteration : 045, Loss on trainig: 2.4632, Accuracy: 0.2812
# Iteration : 046, Loss on trainig: 2.3431, Accuracy: 0.3281
# Iteration : 047, Loss on trainig: 2.4744, Accuracy: 0.3438
# Iteration : 048, Loss on trainig: 2.2453, Accuracy: 0.4062
# Iteration : 049, Loss on trainig: 2.0615, Accuracy: 0.4219
# Iteration : 050, Loss on trainig: 2.4670, Accuracy: 0.3438
# Iteration : 051, Loss on trainig: 1.9959, Accuracy: 0.5312
# Iteration : 052, Loss on trainig: 1.6909, Accuracy: 0.5938
# Iteration : 053, Loss on trainig: 2.4319, Accuracy: 0.4219
# Iteration : 054, Loss on trainig: 2.3070, Accuracy: 0.4375
# Iteration : 055, Loss on trainig: 2.0815, Accuracy: 0.4375
# Iteration : 056, Loss on trainig: 2.1204, Accuracy: 0.4062
# Iteration : 057, Loss on trainig: 2.1775, Accuracy: 0.4062
# Iteration : 058, Loss on trainig: 2.1180, Accuracy: 0.5000
# Iteration : 059, Loss on trainig: 2.1997, Accuracy: 0.3906
# Iteration : 060, Loss on trainig: 1.9770, Accuracy: 0.4375
# Iteration : 061, Loss on trainig: 2.2296, Accuracy: 0.3906
# Iteration : 062, Loss on trainig: 1.9967, Accuracy: 0.4062
# Iteration : 063, Loss on trainig: 2.3350, Accuracy: 0.4219
# Iteration : 064, Loss on trainig: 2.0947, Accuracy: 0.4375
# Iteration : 065, Loss on trainig: 2.1095, Accuracy: 0.4219
# Iteration : 066, Loss on trainig: 2.2824, Accuracy: 0.3906
# Iteration : 067, Loss on trainig: 1.9407, Accuracy: 0.5000
# Iteration : 068, Loss on trainig: 1.9737, Accuracy: 0.4688
# Iteration : 069, Loss on trainig: 2.4297, Accuracy: 0.4219
# Iteration : 070, Loss on trainig: 2.3034, Accuracy: 0.3594
# Iteration : 071, Loss on trainig: 2.5146, Accuracy: 0.3438
# Iteration : 072, Loss on trainig: 2.4186, Accuracy: 0.3438
# Iteration : 073, Loss on trainig: 2.2411, Accuracy: 0.4375
# Iteration : 074, Loss on trainig: 2.2804, Accuracy: 0.4062
# Iteration : 075, Loss on trainig: 2.2089, Accuracy: 0.4375
# Iteration : 076, Loss on trainig: 2.0959, Accuracy: 0.4531
# Iteration : 077, Loss on trainig: 2.2267, Accuracy: 0.3594
# Iteration : 078, Loss on trainig: 1.8104, Accuracy: 0.5312
# Iteration : 079, Loss on trainig: 1.9409, Accuracy: 0.4844
# Iteration : 080, Loss on trainig: 2.0044, Accuracy: 0.4062
# Iteration : 081, Loss on trainig: 2.0832, Accuracy: 0.4375
# Iteration : 082, Loss on trainig: 1.9766, Accuracy: 0.4531
# Iteration : 083, Loss on trainig: 1.7395, Accuracy: 0.5469
# Iteration : 084, Loss on trainig: 2.2736, Accuracy: 0.4062
# Iteration : 085, Loss on trainig: 2.0006, Accuracy: 0.4062
# Iteration : 086, Loss on trainig: 1.9237, Accuracy: 0.5312
# Iteration : 087, Loss on trainig: 2.0972, Accuracy: 0.4688
# Iteration : 088, Loss on trainig: 1.8643, Accuracy: 0.5312
# Iteration : 089, Loss on trainig: 2.3951, Accuracy: 0.3594
# Iteration : 090, Loss on trainig: 2.1023, Accuracy: 0.4062
# Iteration : 091, Loss on trainig: 1.8469, Accuracy: 0.5312
# Iteration : 092, Loss on trainig: 1.9308, Accuracy: 0.5469
# Iteration : 093, Loss on trainig: 2.3930, Accuracy: 0.3125
# Iteration : 094, Loss on trainig: 2.1215, Accuracy: 0.4375
# Iteration : 095, Loss on trainig: 1.8541, Accuracy: 0.5312
# Iteration : 096, Loss on trainig: 1.9959, Accuracy: 0.5000
# Iteration : 097, Loss on trainig: 1.9291, Accuracy: 0.4219
# Iteration : 098, Loss on trainig: 2.0276, Accuracy: 0.3750
# Iteration : 099, Loss on trainig: 2.0346, Accuracy: 0.4062
# Iteration : 100, Loss on trainig: 2.0150, Accuracy: 0.4688
# Iteration : 101, Loss on trainig: 1.9147, Accuracy: 0.4531
# Iteration : 102, Loss on trainig: 1.6850, Accuracy: 0.5833
# Epoch : 2, Training: Loss: f2.1422887261825023, Accuracy: 42.39926739198967%,
# 		Validation : Loss : 1.1480794468835398, Accuracy: 67.35941321750725%
#  *** Training Ended ***

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
with torch.no_grad():
 
    model.eval()

    for j, (inputs, labels) in enumerate(validationLoader):
        inputs = inputs.to('cuda')
        labels = labels.to('cuda')
 
        # Forward pass - compute outputs on input data using the model
        outputs = model(inputs)
 
        # Compute loss
        loss = criterion(outputs, labels)
 
        # Compute total loss
        valid_loss += loss.item() * inputs.size(0)
 
        # Calculate  accuracy
        ret, predictions = torch.max(outputs.data, 1)
        correct_counts = predictions.eq(labels.data.view_as(predictions))
 
        # compute the mean
        acc = torch.mean(correct_counts.type(torch.FloatTensor))
 
        # Compute total accuracy 
        valid_acc += acc.item() * inputs.size(0)
 
        print("Validation number: {:03d}, Validation: Loss: {:.4f}, Accuracy: {:.4f}".format(j, loss.item(), acc.item()))
# Out:
# Validation number: 000, Validation: Loss: 1.6939, Accuracy: 0.5625
# Validation number: 001, Validation: Loss: 1.5351, Accuracy: 0.5312
# Validation number: 002, Validation: Loss: 0.9158, Accuracy: 0.6875
# Validation number: 003, Validation: Loss: 0.9534, Accuracy: 0.7188
# Validation number: 004, Validation: Loss: 1.2889, Accuracy: 0.6562
# Validation number: 005, Validation: Loss: 0.9277, Accuracy: 0.7812
# Validation number: 006, Validation: Loss: 1.1881, Accuracy: 0.5938
# Validation number: 007, Validation: Loss: 1.3544, Accuracy: 0.6562
# Validation number: 008, Validation: Loss: 0.8782, Accuracy: 0.7188
# Validation number: 009, Validation: Loss: 1.0971, Accuracy: 0.7188
# Validation number: 010, Validation: Loss: 1.0469, Accuracy: 0.6875
# Validation number: 011, Validation: Loss: 1.6354, Accuracy: 0.5938
# Validation number: 012, Validation: Loss: 0.8579, Accuracy: 0.8125
# Validation number: 013, Validation: Loss: 1.1423, Accuracy: 0.5938
# Validation number: 014, Validation: Loss: 0.9605, Accuracy: 0.7500
# Validation number: 015, Validation: Loss: 0.7457, Accuracy: 0.8438
# Validation number: 016, Validation: Loss: 0.9688, Accuracy: 0.7500
# Validation number: 017, Validation: Loss: 1.1933, Accuracy: 0.7188
# Validation number: 018, Validation: Loss: 1.2202, Accuracy: 0.6250
# Validation number: 019, Validation: Loss: 1.0747, Accuracy: 0.7188
# Validation number: 020, Validation: Loss: 1.0112, Accuracy: 0.6875
# Validation number: 021, Validation: Loss: 1.4287, Accuracy: 0.5938
# Validation number: 022, Validation: Loss: 1.1643, Accuracy: 0.5938
# Validation number: 023, Validation: Loss: 1.2818, Accuracy: 0.6250
# Validation number: 024, Validation: Loss: 1.3086, Accuracy: 0.5938
# Validation number: 025, Validation: Loss: 0.8439, Accuracy: 0.7222

# %%
correct,total = 0,0
model.eval()
model.to('cuda')
with torch.no_grad():        
    for data in testLoader:    
        img, lbl = data
        img, lbl = img.to('cuda'), lbl.to('cuda')
        outputs = model(img)
        _, predicted = torch.max(outputs.data, 1)
        total += lbl.size(0)
        correct += (predicted == lbl).sum().item()        
            
print('Accuracy is: %d%%' % (100 * correct / total))
# Out:
# Accuracy is: 63%

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint 
model.class_to_idx = image_datasets['train'].class_to_idx
model.cpu
torch.save ({'structure' :'vgg16',
              'hiddenLayer_1':120,
              'state_dict': model.state_dict(),
              'class_to_idx': model.class_to_idx},
               'checkpoint.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model

def loadCheckpoint(path='checkpoint.pth'):
    checkpoint = torch.load('checkpoint.pth')
    model.cuda()
 #   for pr in model.parameters():
 #       pr.requires_grad = False

    structure = checkpoint['structure']
    hiddenLayer_1 = checkpoint['hiddenLayer_1']
    model.class_to_idx = checkpoint['class_to_idx']
    model.state_dict(checkpoint['state_dict'])
    return model


print(loadCheckpoint())
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (inputs): Linear(in_features=25088, out_features=120, bias=True)
#     (rl1): ReLU()
#     (dropout): Dropout(p=0.5)
#     (hiddenLayer_1): Linear(in_features=120, out_features=90, bias=True)
#     (rl2): ReLU()
#     (hiddenLayer_2): Linear(in_features=90, out_features=70, bias=True)
#     (rl3): ReLU()
#     (hiddenLayer_3): Linear(in_features=70, out_features=102, bias=True)
#     (output): LogSoftmax()
#   )
# )

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    
    # TODO: Process a PIL image for use in a PyTorch model

    img = PIL.Image.open(image)
   
   # prepoceess = transforms.Compose([
   #     transforms.Resize(256),
   #     transforms.CenterCrop(224),
   #     transforms.ToTensor(),
   #     transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
   # ])
   # img = prepoceess(proccessedImg)
    
   # return img


    original_width, original_height = img.size
    if original_width < original_height:
        size=[256, 256**600]
    else: 
        size=[256**600, 256]
        
    img.thumbnail(size)
   

    center = original_width/4, original_height/4
    left, top, right, bottom = center[0]-(244/2), center[1]-(244/2), center[0]+(244/2), center[1]+(244/2)
    img = img.crop((left, top, right, bottom))

    numpy_img = np.array(img)/255 
    # Normalize each color channel
    mean = [0.485, 0.456, 0.406]
    std = [0.229, 0.224, 0.225]
    numpy_img = (numpy_img-mean)/std
        
    numpy_img = numpy_img.transpose(2, 0, 1)
    
    return numpy_img

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    if ax is None:
        fig, ax = plt.subplots()

    image = image.transpose((1, 2, 0))
    
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax


#try with random image
import random, os
img = random.choice(os.listdir('./flowers/test/7/'))
img_path = './flowers/test/7/' + img


with Image.open(img_path) as image:
    imshow(process_image(img_path))

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, topK=5):
    
    
    with torch.no_grad():
        model.to("cpu")
        image = process_image(image_path)
        image = torch.from_numpy(np.asarray(image).astype('float'))
        image.unsqueeze_(0)
        image = image.float()
  
        outputs = model(image)
        probs, classes = torch.exp(outputs).topk(topK)
        return probs[0].tolist(), classes[0].add(1).tolist()

# %%
img2 = random.choice(os.listdir('./flowers/test/7/'))
img_path2 = './flowers/test/7/' + img2
    
prob, clas = predict(img_path2, model)
print(prob)
print(clas)
flowers = [cat_to_name[str(x)]  for x in clas]
print(flowers)
# Out:
# [0.7509547472000122, 0.07427144050598145, 0.02960427664220333, 0.02266721986234188, 0.021391531452536583]
# [70, 89, 51, 86, 33]
# ['tree poppy', 'watercress', 'petunia', 'tree mallow', 'love in the mist']

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
def display_prediction(img_path2, model):

    # Set up plot
    plt.figure(figsize = (6,10))
    xx = plt.subplot(2,1,1)


    # Make prediction
    probs, clas = predict(img_path2, model) 
    flowers = [cat_to_name[str(a)]  for a in clas]

    # Plot flower
    img = process_image(img_path2)
    imshow(img, xx);

    # Plot bar chart
    plt.subplot(2,1,2)
    sb.barplot(x=probs, y=flowers, color=sb.color_palette()[0]);
    plt.show()
    return None

# %%
display_prediction(img_path2,model)
