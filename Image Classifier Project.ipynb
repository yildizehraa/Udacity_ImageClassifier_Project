# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Imports here
import numpy as np
import seaborn as sb
import torch
from torch import nn
from torch import tensor
from torch import optim
import matplotlib.pyplot as plt
import time
import json
import PIL
import torchvision
import torch.nn.functional as Fl
from torch.autograd import Variable
from torchvision import datasets, transforms,models 
import argparse
from collections import OrderedDict
from PIL import Image

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets
data_transforms = {
    'train' : transforms.Compose([
        transforms.RandomResizedCrop(size=224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.454, 0.406],
                            [0.229, 0.224, 0.225])
    ]),
    'valid' : transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.454, 0.406],
                            [0.229, 0.224, 0.225])
    ]),
    'test' : transforms.Compose([
        transforms.Resize(size=256),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.454, 0.406],
                             [0.229, 0.224, 0.225])
    ])
                }

# TODO: Load the datasets with ImageFolder
image_datasets = {
    'train' : datasets.ImageFolder(train_dir, transform=data_transforms['train']),
    'valid' : datasets.ImageFolder(valid_dir, transform=data_transforms['valid']),
    'test' : datasets.ImageFolder(test_dir, transform=data_transforms['test'])
}


trainLoader = torch.utils.data.DataLoader(image_datasets['train'], batch_size = 64, shuffle = True)
validationLoader = torch.utils.data.DataLoader(image_datasets['valid'], batch_size = 32, shuffle = True)
testLoader = torch.utils.data.DataLoader(image_datasets['test'], batch_size = 32, shuffle = True)

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# **Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
# TODO: Build and train your network

model = models.vgg16(pretrained=True)

for pr in model.parameters():
    pr.required_grad = False

# %%
   
### Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
classifier = nn.Sequential(OrderedDict([
            ('inputs', nn.Linear(25088, 120)),
            ('rl1', nn.ReLU()),
            ('dropout', nn.Dropout(0.5)),
            ('hiddenLayer_1', nn.Linear(120, 90)),
            ('rl2', nn.ReLU()),
            ('hiddenLayer_2', nn.Linear(90,70)),
            ('rl3', nn.ReLU()),
            ('hiddenLayer_3', nn.Linear(70, 102)),
            ('output', nn.LogSoftmax(dim=1))]))

model.classifier = classifier
    
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.classifier.parameters(), lr=0.001)

model.cuda()
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (inputs): Linear(in_features=25088, out_features=120, bias=True)
#     (rl1): ReLU()
#     (dropout): Dropout(p=0.5)
#     (hiddenLayer_1): Linear(in_features=120, out_features=90, bias=True)
#     (rl2): ReLU()
#     (hiddenLayer_2): Linear(in_features=90, out_features=70, bias=True)
#     (rl3): ReLU()
#     (hiddenLayer_3): Linear(in_features=70, out_features=102, bias=True)
#     (output): LogSoftmax()
#   )
# )

# %%
#Train the classifier layers using backpropagation using the pre-trained network to get the features
#Track the loss and accuracy on the validation set to determine the best hyperparameters

epochs = 5

#epochs = 10

print(' *** Training Started *** ')

for epoch in range(epochs):
    model.train()
    print("Epoch: {}/{}".format(epoch+1, epochs))
    trainLoss_total = 0.0
    trainAcc = 0.0
    validloss = 0.0
    validacc = 0.0
    for i, (inputs, labels) in enumerate(trainLoader):
        inputs = inputs.to('cuda')
        labels = labels.to('cuda')
        
        optimizer.zero_grad()
        
        outputs = model.forward(inputs)
    
        loss = criterion(outputs, labels)
        loss.backward()
        
        optimizer.step()
        
        trainLoss_total += loss.item() * inputs.size(0)
                
        #accuracy
        ret, ps = torch.max(outputs.data, 1)
        total = ps.eq(labels.data.view_as(ps))
        
        # compute mean
        accuracy = torch.mean(total.type(torch.FloatTensor))
        
        trainAcc += accuracy.item() * inputs.size(0)
               
        print("Iteration : {:03d}, Loss on trainig: {:.4f}, Accuracy: {:.4f}".format(i, loss.item(), accuracy.item()))
        
print(' *** Training Ended *** ')
# Out:
#  *** Training Started ***
# Epoch: 1/5
# Iteration : 000, Loss on trainig: 4.6254, Accuracy: 0.0000
# Iteration : 001, Loss on trainig: 4.6321, Accuracy: 0.0000
# Iteration : 002, Loss on trainig: 4.6063, Accuracy: 0.0000
# Iteration : 003, Loss on trainig: 4.6106, Accuracy: 0.0312
# Iteration : 004, Loss on trainig: 4.5778, Accuracy: 0.0156
# Iteration : 005, Loss on trainig: 4.6705, Accuracy: 0.0156
# Iteration : 006, Loss on trainig: 4.5164, Accuracy: 0.0312
# Iteration : 007, Loss on trainig: 4.6065, Accuracy: 0.0469
# Iteration : 008, Loss on trainig: 4.5247, Accuracy: 0.0469
# Iteration : 009, Loss on trainig: 4.6457, Accuracy: 0.0156
# Iteration : 010, Loss on trainig: 4.5581, Accuracy: 0.0312
# Iteration : 011, Loss on trainig: 4.6675, Accuracy: 0.0000
# Iteration : 012, Loss on trainig: 4.5682, Accuracy: 0.0625
# Iteration : 013, Loss on trainig: 4.4950, Accuracy: 0.0312
# Iteration : 014, Loss on trainig: 4.5499, Accuracy: 0.0156
# Iteration : 015, Loss on trainig: 4.5968, Accuracy: 0.0312
# Iteration : 016, Loss on trainig: 4.3966, Accuracy: 0.0469
# Iteration : 017, Loss on trainig: 4.5207, Accuracy: 0.0312
# Iteration : 018, Loss on trainig: 4.5361, Accuracy: 0.0469
# Iteration : 019, Loss on trainig: 4.5897, Accuracy: 0.0469
# Iteration : 020, Loss on trainig: 4.5092, Accuracy: 0.0469
# Iteration : 021, Loss on trainig: 4.4653, Accuracy: 0.0625
# Iteration : 022, Loss on trainig: 4.3600, Accuracy: 0.1094
# Iteration : 023, Loss on trainig: 4.3871, Accuracy: 0.0781
# Iteration : 024, Loss on trainig: 4.4257, Accuracy: 0.0938
# Iteration : 025, Loss on trainig: 4.5419, Accuracy: 0.0625
# Iteration : 026, Loss on trainig: 4.3611, Accuracy: 0.0938
# Iteration : 027, Loss on trainig: 4.3254, Accuracy: 0.1094
# Iteration : 028, Loss on trainig: 4.4088, Accuracy: 0.0625
# Iteration : 029, Loss on trainig: 4.3713, Accuracy: 0.0938
# Iteration : 030, Loss on trainig: 4.4537, Accuracy: 0.0312
# Iteration : 031, Loss on trainig: 4.2520, Accuracy: 0.1250
# Iteration : 032, Loss on trainig: 4.2656, Accuracy: 0.0781
# Iteration : 033, Loss on trainig: 4.2604, Accuracy: 0.1094
# Iteration : 034, Loss on trainig: 4.2196, Accuracy: 0.0781
# Iteration : 035, Loss on trainig: 4.2713, Accuracy: 0.0625
# Iteration : 036, Loss on trainig: 4.4227, Accuracy: 0.0469
# Iteration : 037, Loss on trainig: 4.2668, Accuracy: 0.0625
# Iteration : 038, Loss on trainig: 4.1341, Accuracy: 0.1094
# Iteration : 039, Loss on trainig: 4.2725, Accuracy: 0.0781
# Iteration : 040, Loss on trainig: 4.0644, Accuracy: 0.1562
# Iteration : 041, Loss on trainig: 3.9288, Accuracy: 0.1875
# Iteration : 042, Loss on trainig: 4.0355, Accuracy: 0.1406
# Iteration : 043, Loss on trainig: 3.9633, Accuracy: 0.1250
# Iteration : 044, Loss on trainig: 4.1630, Accuracy: 0.0938
# Iteration : 045, Loss on trainig: 4.3700, Accuracy: 0.1094
# Iteration : 046, Loss on trainig: 4.2484, Accuracy: 0.0625
# Iteration : 047, Loss on trainig: 4.2705, Accuracy: 0.0938
# Iteration : 048, Loss on trainig: 4.1990, Accuracy: 0.0781
# Iteration : 049, Loss on trainig: 4.0644, Accuracy: 0.0938
# Iteration : 050, Loss on trainig: 3.9648, Accuracy: 0.1562
# Iteration : 051, Loss on trainig: 4.0384, Accuracy: 0.1719
# Iteration : 052, Loss on trainig: 4.1645, Accuracy: 0.0781
# Iteration : 053, Loss on trainig: 4.1678, Accuracy: 0.0938
# Iteration : 054, Loss on trainig: 4.0167, Accuracy: 0.1562
# Iteration : 055, Loss on trainig: 4.1004, Accuracy: 0.1094
# Iteration : 056, Loss on trainig: 4.0297, Accuracy: 0.1094
# Iteration : 057, Loss on trainig: 4.0058, Accuracy: 0.1250
# Iteration : 058, Loss on trainig: 3.7910, Accuracy: 0.1250
# Iteration : 059, Loss on trainig: 3.8595, Accuracy: 0.2188
# Iteration : 060, Loss on trainig: 4.2294, Accuracy: 0.0625
# Iteration : 061, Loss on trainig: 3.8098, Accuracy: 0.1406
# Iteration : 062, Loss on trainig: 3.8618, Accuracy: 0.1094
# Iteration : 063, Loss on trainig: 3.8656, Accuracy: 0.1562
# Iteration : 064, Loss on trainig: 3.7833, Accuracy: 0.1406
# Iteration : 065, Loss on trainig: 3.9564, Accuracy: 0.1406
# Iteration : 066, Loss on trainig: 3.8362, Accuracy: 0.1250
# Iteration : 067, Loss on trainig: 4.0443, Accuracy: 0.0938
# Iteration : 068, Loss on trainig: 4.0348, Accuracy: 0.1094
# Iteration : 069, Loss on trainig: 3.8938, Accuracy: 0.0781
# Iteration : 070, Loss on trainig: 3.9352, Accuracy: 0.0938
# Iteration : 071, Loss on trainig: 3.8693, Accuracy: 0.1406
# Iteration : 072, Loss on trainig: 3.6124, Accuracy: 0.1250
# Iteration : 073, Loss on trainig: 3.7366, Accuracy: 0.1719
# Iteration : 074, Loss on trainig: 3.5200, Accuracy: 0.1719
# Iteration : 075, Loss on trainig: 3.9734, Accuracy: 0.0938
# Iteration : 076, Loss on trainig: 3.5102, Accuracy: 0.2344
# Iteration : 077, Loss on trainig: 3.5218, Accuracy: 0.2656
# Iteration : 078, Loss on trainig: 3.5541, Accuracy: 0.1875
# Iteration : 079, Loss on trainig: 3.2348, Accuracy: 0.3281
# Iteration : 080, Loss on trainig: 3.6078, Accuracy: 0.1562
# Iteration : 081, Loss on trainig: 3.1722, Accuracy: 0.2656
# Iteration : 082, Loss on trainig: 3.6116, Accuracy: 0.1562
# Iteration : 083, Loss on trainig: 3.4518, Accuracy: 0.2656
# Iteration : 084, Loss on trainig: 3.2380, Accuracy: 0.2500
# Iteration : 085, Loss on trainig: 3.6463, Accuracy: 0.1719
# Iteration : 086, Loss on trainig: 3.8339, Accuracy: 0.1250
# Iteration : 087, Loss on trainig: 3.1316, Accuracy: 0.2344
# Iteration : 088, Loss on trainig: 3.4345, Accuracy: 0.2188
# Iteration : 089, Loss on trainig: 3.4782, Accuracy: 0.2188
# Iteration : 090, Loss on trainig: 3.4693, Accuracy: 0.2188
# Iteration : 091, Loss on trainig: 3.2509, Accuracy: 0.2656
# Iteration : 092, Loss on trainig: 3.2455, Accuracy: 0.3281
# Iteration : 093, Loss on trainig: 3.3683, Accuracy: 0.2344
# Iteration : 094, Loss on trainig: 3.5992, Accuracy: 0.1875
# Iteration : 095, Loss on trainig: 3.3942, Accuracy: 0.2031
# Iteration : 096, Loss on trainig: 3.5031, Accuracy: 0.2812
# Iteration : 097, Loss on trainig: 3.2449, Accuracy: 0.2656
# Iteration : 098, Loss on trainig: 3.2090, Accuracy: 0.2500
# Iteration : 099, Loss on trainig: 3.1581, Accuracy: 0.2500
# Iteration : 100, Loss on trainig: 3.1763, Accuracy: 0.2812
# Iteration : 101, Loss on trainig: 3.1268, Accuracy: 0.2812
# Iteration : 102, Loss on trainig: 3.3226, Accuracy: 0.2917
# Epoch: 2/5
# Iteration : 000, Loss on trainig: 2.9701, Accuracy: 0.2812
# Iteration : 001, Loss on trainig: 3.2769, Accuracy: 0.1719
# Iteration : 002, Loss on trainig: 3.2829, Accuracy: 0.2031
# Iteration : 003, Loss on trainig: 2.9723, Accuracy: 0.2344
# Iteration : 004, Loss on trainig: 3.0821, Accuracy: 0.2812
# Iteration : 005, Loss on trainig: 3.2353, Accuracy: 0.2656
# Iteration : 006, Loss on trainig: 3.1470, Accuracy: 0.3281
# Iteration : 007, Loss on trainig: 3.1686, Accuracy: 0.2188
# Iteration : 008, Loss on trainig: 3.2378, Accuracy: 0.2969
# Iteration : 009, Loss on trainig: 3.0857, Accuracy: 0.3125
# Iteration : 010, Loss on trainig: 3.1922, Accuracy: 0.2031
# Iteration : 011, Loss on trainig: 3.0349, Accuracy: 0.3125
# Iteration : 012, Loss on trainig: 3.1175, Accuracy: 0.2500
# Iteration : 013, Loss on trainig: 2.7551, Accuracy: 0.4219
# Iteration : 014, Loss on trainig: 2.9724, Accuracy: 0.3594
# Iteration : 015, Loss on trainig: 2.5471, Accuracy: 0.3594
# Iteration : 016, Loss on trainig: 2.8879, Accuracy: 0.2344
# Iteration : 017, Loss on trainig: 2.9685, Accuracy: 0.2031
# Iteration : 018, Loss on trainig: 3.2948, Accuracy: 0.1719
# Iteration : 019, Loss on trainig: 3.1872, Accuracy: 0.2344
# Iteration : 020, Loss on trainig: 2.6901, Accuracy: 0.3906
# Iteration : 021, Loss on trainig: 2.7541, Accuracy: 0.3906
# Iteration : 022, Loss on trainig: 2.8564, Accuracy: 0.2656
# Iteration : 023, Loss on trainig: 3.1521, Accuracy: 0.2500
# Iteration : 024, Loss on trainig: 3.0696, Accuracy: 0.2344
# Iteration : 025, Loss on trainig: 3.2895, Accuracy: 0.1719
# Iteration : 026, Loss on trainig: 2.9990, Accuracy: 0.2656
# Iteration : 027, Loss on trainig: 2.7019, Accuracy: 0.2812
# Iteration : 028, Loss on trainig: 2.7713, Accuracy: 0.3125
# Iteration : 029, Loss on trainig: 2.8010, Accuracy: 0.3125
# Iteration : 030, Loss on trainig: 2.8970, Accuracy: 0.2344
# Iteration : 031, Loss on trainig: 2.9100, Accuracy: 0.3906
# Iteration : 032, Loss on trainig: 2.6308, Accuracy: 0.3594
# Iteration : 033, Loss on trainig: 3.2139, Accuracy: 0.2188
# Iteration : 034, Loss on trainig: 3.0463, Accuracy: 0.2812
# Iteration : 035, Loss on trainig: 3.0931, Accuracy: 0.1406
# Iteration : 036, Loss on trainig: 2.9380, Accuracy: 0.2812
# Iteration : 037, Loss on trainig: 2.7325, Accuracy: 0.3125
# Iteration : 038, Loss on trainig: 2.6909, Accuracy: 0.2656
# Iteration : 039, Loss on trainig: 2.5196, Accuracy: 0.3281
# Iteration : 040, Loss on trainig: 3.1188, Accuracy: 0.2344
# Iteration : 041, Loss on trainig: 2.5508, Accuracy: 0.3594
# Iteration : 042, Loss on trainig: 2.4376, Accuracy: 0.3594
# Iteration : 043, Loss on trainig: 2.8357, Accuracy: 0.2812
# Iteration : 044, Loss on trainig: 2.6748, Accuracy: 0.3281
# Iteration : 045, Loss on trainig: 2.9363, Accuracy: 0.2500
# Iteration : 046, Loss on trainig: 3.0511, Accuracy: 0.2500
# Iteration : 047, Loss on trainig: 2.9519, Accuracy: 0.2500
# Iteration : 048, Loss on trainig: 2.7638, Accuracy: 0.2656
# Iteration : 049, Loss on trainig: 2.8824, Accuracy: 0.3438
# Iteration : 050, Loss on trainig: 2.6450, Accuracy: 0.2969
# Iteration : 051, Loss on trainig: 2.9957, Accuracy: 0.2812
# Iteration : 052, Loss on trainig: 2.5292, Accuracy: 0.2812
# Iteration : 053, Loss on trainig: 2.6787, Accuracy: 0.2656
# Iteration : 054, Loss on trainig: 2.4186, Accuracy: 0.3594
# Iteration : 055, Loss on trainig: 2.7262, Accuracy: 0.2656
# Iteration : 056, Loss on trainig: 2.9606, Accuracy: 0.2656
# Iteration : 057, Loss on trainig: 2.9575, Accuracy: 0.2188
# Iteration : 058, Loss on trainig: 2.7382, Accuracy: 0.2500
# Iteration : 059, Loss on trainig: 2.4977, Accuracy: 0.3125
# Iteration : 060, Loss on trainig: 2.6487, Accuracy: 0.3125
# Iteration : 061, Loss on trainig: 2.3266, Accuracy: 0.4688
# Iteration : 062, Loss on trainig: 2.6880, Accuracy: 0.2656
# Iteration : 063, Loss on trainig: 3.0167, Accuracy: 0.2031
# Iteration : 064, Loss on trainig: 2.8707, Accuracy: 0.2969
# Iteration : 065, Loss on trainig: 2.8330, Accuracy: 0.2188
# Iteration : 066, Loss on trainig: 2.7213, Accuracy: 0.3281
# Iteration : 067, Loss on trainig: 2.5507, Accuracy: 0.3906
# Iteration : 068, Loss on trainig: 2.6127, Accuracy: 0.4062
# Iteration : 069, Loss on trainig: 2.8514, Accuracy: 0.3281
# Iteration : 070, Loss on trainig: 2.6126, Accuracy: 0.3750
# Iteration : 071, Loss on trainig: 2.3736, Accuracy: 0.4062
# Iteration : 072, Loss on trainig: 2.6686, Accuracy: 0.3438
# Iteration : 073, Loss on trainig: 2.6697, Accuracy: 0.3594
# Iteration : 074, Loss on trainig: 2.2577, Accuracy: 0.3594
# Iteration : 075, Loss on trainig: 2.4646, Accuracy: 0.4062
# Iteration : 076, Loss on trainig: 2.3013, Accuracy: 0.4062
# Iteration : 077, Loss on trainig: 2.4901, Accuracy: 0.3281
# Iteration : 078, Loss on trainig: 2.4676, Accuracy: 0.3594
# Iteration : 079, Loss on trainig: 2.9838, Accuracy: 0.2656
# Iteration : 080, Loss on trainig: 2.5718, Accuracy: 0.2812
# Iteration : 081, Loss on trainig: 3.0810, Accuracy: 0.2656
# Iteration : 082, Loss on trainig: 2.3445, Accuracy: 0.3750
# Iteration : 083, Loss on trainig: 2.5947, Accuracy: 0.2969
# Iteration : 084, Loss on trainig: 2.5969, Accuracy: 0.2656
# Iteration : 085, Loss on trainig: 2.8677, Accuracy: 0.2344
# Iteration : 086, Loss on trainig: 2.3070, Accuracy: 0.3281
# Iteration : 087, Loss on trainig: 2.4611, Accuracy: 0.3594
# Iteration : 088, Loss on trainig: 2.6428, Accuracy: 0.3281
# Iteration : 089, Loss on trainig: 2.5067, Accuracy: 0.3125
# Iteration : 090, Loss on trainig: 2.4621, Accuracy: 0.3281
# Iteration : 091, Loss on trainig: 2.1989, Accuracy: 0.4219
# Iteration : 092, Loss on trainig: 2.6815, Accuracy: 0.3125
# Iteration : 093, Loss on trainig: 2.2513, Accuracy: 0.3906
# Iteration : 094, Loss on trainig: 2.2126, Accuracy: 0.3594
# Iteration : 095, Loss on trainig: 2.4618, Accuracy: 0.2969
# Iteration : 096, Loss on trainig: 2.5209, Accuracy: 0.3281
# Iteration : 097, Loss on trainig: 2.4953, Accuracy: 0.3438
# Iteration : 098, Loss on trainig: 2.4560, Accuracy: 0.3750
# Iteration : 099, Loss on trainig: 2.5897, Accuracy: 0.3125
# Iteration : 100, Loss on trainig: 2.5407, Accuracy: 0.3281
# Iteration : 101, Loss on trainig: 2.2786, Accuracy: 0.3750
# Iteration : 102, Loss on trainig: 2.9489, Accuracy: 0.2917
# Epoch: 3/5
# Iteration : 000, Loss on trainig: 2.1366, Accuracy: 0.3281
# Iteration : 001, Loss on trainig: 2.4507, Accuracy: 0.3750
# Iteration : 002, Loss on trainig: 2.4625, Accuracy: 0.4688
# Iteration : 003, Loss on trainig: 2.1844, Accuracy: 0.4219
# Iteration : 004, Loss on trainig: 2.5623, Accuracy: 0.3906
# Iteration : 005, Loss on trainig: 2.5071, Accuracy: 0.3125
# Iteration : 006, Loss on trainig: 2.4658, Accuracy: 0.3125
# Iteration : 007, Loss on trainig: 2.4381, Accuracy: 0.3438
# Iteration : 008, Loss on trainig: 2.6237, Accuracy: 0.2969
# Iteration : 009, Loss on trainig: 2.7796, Accuracy: 0.3438
# Iteration : 010, Loss on trainig: 2.4978, Accuracy: 0.3281
# Iteration : 011, Loss on trainig: 2.2883, Accuracy: 0.3438
# Iteration : 012, Loss on trainig: 2.6854, Accuracy: 0.2969
# Iteration : 013, Loss on trainig: 2.2539, Accuracy: 0.4688
# Iteration : 014, Loss on trainig: 2.2769, Accuracy: 0.4375
# Iteration : 015, Loss on trainig: 2.4011, Accuracy: 0.3438
# Iteration : 016, Loss on trainig: 2.5915, Accuracy: 0.3438
# Iteration : 017, Loss on trainig: 2.3978, Accuracy: 0.4062
# Iteration : 018, Loss on trainig: 2.6178, Accuracy: 0.3594
# Iteration : 019, Loss on trainig: 2.2325, Accuracy: 0.4062
# Iteration : 020, Loss on trainig: 2.3474, Accuracy: 0.4375
# Iteration : 021, Loss on trainig: 1.9622, Accuracy: 0.3750
# Iteration : 022, Loss on trainig: 2.7823, Accuracy: 0.3281
# Iteration : 023, Loss on trainig: 2.1134, Accuracy: 0.4219
# Iteration : 024, Loss on trainig: 2.4904, Accuracy: 0.3281
# Iteration : 025, Loss on trainig: 2.2608, Accuracy: 0.4375
# Iteration : 026, Loss on trainig: 2.5425, Accuracy: 0.3281
# Iteration : 027, Loss on trainig: 2.0561, Accuracy: 0.4531
# Iteration : 028, Loss on trainig: 2.3964, Accuracy: 0.4844
# Iteration : 029, Loss on trainig: 2.2679, Accuracy: 0.4062
# Iteration : 030, Loss on trainig: 2.4225, Accuracy: 0.3281
# Iteration : 031, Loss on trainig: 2.0582, Accuracy: 0.4531
# Iteration : 032, Loss on trainig: 2.1907, Accuracy: 0.4375
# Iteration : 033, Loss on trainig: 2.2773, Accuracy: 0.4062
# Iteration : 034, Loss on trainig: 2.1709, Accuracy: 0.4375
# Iteration : 035, Loss on trainig: 2.5500, Accuracy: 0.3750
# Iteration : 036, Loss on trainig: 2.2375, Accuracy: 0.4062
# Iteration : 037, Loss on trainig: 2.2333, Accuracy: 0.3906
# Iteration : 038, Loss on trainig: 2.1772, Accuracy: 0.3438
# Iteration : 039, Loss on trainig: 2.0990, Accuracy: 0.4375
# Iteration : 040, Loss on trainig: 2.3328, Accuracy: 0.3594
# Iteration : 041, Loss on trainig: 2.4941, Accuracy: 0.4219
# Iteration : 042, Loss on trainig: 2.0993, Accuracy: 0.4375
# Iteration : 043, Loss on trainig: 2.3815, Accuracy: 0.2969
# Iteration : 044, Loss on trainig: 2.2874, Accuracy: 0.4219
# Iteration : 045, Loss on trainig: 2.0840, Accuracy: 0.3750
# Iteration : 046, Loss on trainig: 2.0869, Accuracy: 0.4219
# Iteration : 047, Loss on trainig: 2.7365, Accuracy: 0.2812
# Iteration : 048, Loss on trainig: 2.3937, Accuracy: 0.3594
# Iteration : 049, Loss on trainig: 2.3665, Accuracy: 0.3594
# Iteration : 050, Loss on trainig: 2.2964, Accuracy: 0.3750
# Iteration : 051, Loss on trainig: 2.3600, Accuracy: 0.3750
# Iteration : 052, Loss on trainig: 2.1129, Accuracy: 0.4219
# Iteration : 053, Loss on trainig: 2.0973, Accuracy: 0.3906
# Iteration : 054, Loss on trainig: 1.7623, Accuracy: 0.5312
# Iteration : 055, Loss on trainig: 2.6454, Accuracy: 0.2969
# Iteration : 056, Loss on trainig: 2.3282, Accuracy: 0.3750
# Iteration : 057, Loss on trainig: 2.4577, Accuracy: 0.3281
# Iteration : 058, Loss on trainig: 2.3128, Accuracy: 0.3594
# Iteration : 059, Loss on trainig: 1.9680, Accuracy: 0.4531
# Iteration : 060, Loss on trainig: 2.3283, Accuracy: 0.4375
# Iteration : 061, Loss on trainig: 2.4545, Accuracy: 0.2500
# Iteration : 062, Loss on trainig: 2.5981, Accuracy: 0.3438
# Iteration : 063, Loss on trainig: 2.0998, Accuracy: 0.4688
# Iteration : 064, Loss on trainig: 2.0491, Accuracy: 0.4062
# Iteration : 065, Loss on trainig: 2.1705, Accuracy: 0.4531
# Iteration : 066, Loss on trainig: 2.1919, Accuracy: 0.4062
# Iteration : 067, Loss on trainig: 2.0586, Accuracy: 0.4531
# Iteration : 068, Loss on trainig: 2.4462, Accuracy: 0.2812
# Iteration : 069, Loss on trainig: 2.3179, Accuracy: 0.4219
# Iteration : 070, Loss on trainig: 2.2737, Accuracy: 0.3438
# Iteration : 071, Loss on trainig: 2.2900, Accuracy: 0.4219
# Iteration : 072, Loss on trainig: 2.3216, Accuracy: 0.3125
# Iteration : 073, Loss on trainig: 2.2438, Accuracy: 0.4531
# Iteration : 074, Loss on trainig: 1.9190, Accuracy: 0.4844
# Iteration : 075, Loss on trainig: 2.1181, Accuracy: 0.4375
# Iteration : 076, Loss on trainig: 2.1588, Accuracy: 0.4375
# Iteration : 077, Loss on trainig: 1.7590, Accuracy: 0.5000
# Iteration : 078, Loss on trainig: 2.5387, Accuracy: 0.3281
# Iteration : 079, Loss on trainig: 2.1921, Accuracy: 0.4062
# Iteration : 080, Loss on trainig: 1.9592, Accuracy: 0.5000
# Iteration : 081, Loss on trainig: 2.1098, Accuracy: 0.4375
# Iteration : 082, Loss on trainig: 2.1128, Accuracy: 0.4062
# Iteration : 083, Loss on trainig: 2.3726, Accuracy: 0.4062
# Iteration : 084, Loss on trainig: 2.0754, Accuracy: 0.3906
# Iteration : 085, Loss on trainig: 2.0501, Accuracy: 0.4375
# Iteration : 086, Loss on trainig: 2.2024, Accuracy: 0.4531
# Iteration : 087, Loss on trainig: 2.1676, Accuracy: 0.5156
# Iteration : 088, Loss on trainig: 2.1801, Accuracy: 0.4219
# Iteration : 089, Loss on trainig: 1.8804, Accuracy: 0.4531
# Iteration : 090, Loss on trainig: 2.1744, Accuracy: 0.4219
# Iteration : 091, Loss on trainig: 2.5368, Accuracy: 0.3438
# Iteration : 092, Loss on trainig: 1.9913, Accuracy: 0.4844
# Iteration : 093, Loss on trainig: 2.2120, Accuracy: 0.3750
# Iteration : 094, Loss on trainig: 2.4166, Accuracy: 0.3906
# Iteration : 095, Loss on trainig: 2.3153, Accuracy: 0.4688
# Iteration : 096, Loss on trainig: 1.9976, Accuracy: 0.4531
# Iteration : 097, Loss on trainig: 2.0134, Accuracy: 0.4531
# Iteration : 098, Loss on trainig: 2.5126, Accuracy: 0.3438
# Iteration : 099, Loss on trainig: 2.1644, Accuracy: 0.3906
# Iteration : 100, Loss on trainig: 2.2707, Accuracy: 0.4219
# Iteration : 101, Loss on trainig: 1.7620, Accuracy: 0.4375
# Iteration : 102, Loss on trainig: 1.8814, Accuracy: 0.5417
# Epoch: 4/5
# Iteration : 000, Loss on trainig: 2.3780, Accuracy: 0.4375
# Iteration : 001, Loss on trainig: 2.3634, Accuracy: 0.4219
# Iteration : 002, Loss on trainig: 1.7527, Accuracy: 0.5156
# Iteration : 003, Loss on trainig: 2.0511, Accuracy: 0.4219
# Iteration : 004, Loss on trainig: 1.9961, Accuracy: 0.4531
# Iteration : 005, Loss on trainig: 2.1629, Accuracy: 0.3750
# Iteration : 006, Loss on trainig: 2.2084, Accuracy: 0.3750
# Iteration : 007, Loss on trainig: 2.1092, Accuracy: 0.4375
# Iteration : 008, Loss on trainig: 2.1715, Accuracy: 0.4062
# Iteration : 009, Loss on trainig: 1.8056, Accuracy: 0.5156
# Iteration : 010, Loss on trainig: 2.0301, Accuracy: 0.5000
# Iteration : 011, Loss on trainig: 2.2250, Accuracy: 0.3594
# Iteration : 012, Loss on trainig: 2.1087, Accuracy: 0.4062
# Iteration : 013, Loss on trainig: 2.1962, Accuracy: 0.4062
# Iteration : 014, Loss on trainig: 1.9505, Accuracy: 0.4219
# Iteration : 015, Loss on trainig: 2.3407, Accuracy: 0.3281
# Iteration : 016, Loss on trainig: 2.0033, Accuracy: 0.4531
# Iteration : 017, Loss on trainig: 1.9423, Accuracy: 0.4688
# Iteration : 018, Loss on trainig: 2.0695, Accuracy: 0.5000
# Iteration : 019, Loss on trainig: 2.1307, Accuracy: 0.3906
# Iteration : 020, Loss on trainig: 1.9722, Accuracy: 0.4219
# Iteration : 021, Loss on trainig: 1.7708, Accuracy: 0.4844
# Iteration : 022, Loss on trainig: 1.7563, Accuracy: 0.5312
# Iteration : 023, Loss on trainig: 2.1270, Accuracy: 0.4531
# Iteration : 024, Loss on trainig: 2.1365, Accuracy: 0.4375
# Iteration : 025, Loss on trainig: 1.7143, Accuracy: 0.5469
# Iteration : 026, Loss on trainig: 2.0430, Accuracy: 0.4375
# Iteration : 027, Loss on trainig: 2.2946, Accuracy: 0.3750
# Iteration : 028, Loss on trainig: 1.9028, Accuracy: 0.5312
# Iteration : 029, Loss on trainig: 2.1376, Accuracy: 0.4844
# Iteration : 030, Loss on trainig: 1.6860, Accuracy: 0.5781
# Iteration : 031, Loss on trainig: 1.9448, Accuracy: 0.5469
# Iteration : 032, Loss on trainig: 2.3035, Accuracy: 0.4219
# Iteration : 033, Loss on trainig: 2.1127, Accuracy: 0.4531
# Iteration : 034, Loss on trainig: 1.4433, Accuracy: 0.5781
# Iteration : 035, Loss on trainig: 2.0124, Accuracy: 0.4844
# Iteration : 036, Loss on trainig: 1.7286, Accuracy: 0.4844
# Iteration : 037, Loss on trainig: 2.1081, Accuracy: 0.4531
# Iteration : 038, Loss on trainig: 1.5175, Accuracy: 0.5781
# Iteration : 039, Loss on trainig: 2.1119, Accuracy: 0.4375
# Iteration : 040, Loss on trainig: 2.2385, Accuracy: 0.4375
# Iteration : 041, Loss on trainig: 1.9758, Accuracy: 0.4062
# Iteration : 042, Loss on trainig: 1.9848, Accuracy: 0.4844
# Iteration : 043, Loss on trainig: 2.0533, Accuracy: 0.4062
# Iteration : 044, Loss on trainig: 1.7303, Accuracy: 0.4531
# Iteration : 045, Loss on trainig: 1.6336, Accuracy: 0.5000
# Iteration : 046, Loss on trainig: 2.2830, Accuracy: 0.3750
# Iteration : 047, Loss on trainig: 1.7787, Accuracy: 0.4688
# Iteration : 048, Loss on trainig: 2.0908, Accuracy: 0.3438
# Iteration : 049, Loss on trainig: 2.0475, Accuracy: 0.4062
# Iteration : 050, Loss on trainig: 1.9580, Accuracy: 0.3906
# Iteration : 051, Loss on trainig: 1.9416, Accuracy: 0.4375
# Iteration : 052, Loss on trainig: 1.8090, Accuracy: 0.5156
# Iteration : 053, Loss on trainig: 1.6365, Accuracy: 0.4844
# Iteration : 054, Loss on trainig: 1.6781, Accuracy: 0.5625
# Iteration : 055, Loss on trainig: 1.7255, Accuracy: 0.4531
# Iteration : 056, Loss on trainig: 2.1989, Accuracy: 0.4688
# Iteration : 057, Loss on trainig: 1.9668, Accuracy: 0.3906
# Iteration : 058, Loss on trainig: 2.2375, Accuracy: 0.4531
# Iteration : 059, Loss on trainig: 2.1234, Accuracy: 0.4375
# Iteration : 060, Loss on trainig: 1.8863, Accuracy: 0.4375
# Iteration : 061, Loss on trainig: 2.3263, Accuracy: 0.3906
# Iteration : 062, Loss on trainig: 2.1181, Accuracy: 0.4062
# Iteration : 063, Loss on trainig: 2.1601, Accuracy: 0.3438
# Iteration : 064, Loss on trainig: 1.9745, Accuracy: 0.4062
# Iteration : 065, Loss on trainig: 1.8869, Accuracy: 0.4062
# Iteration : 066, Loss on trainig: 2.0521, Accuracy: 0.4688
# Iteration : 067, Loss on trainig: 1.8127, Accuracy: 0.4844
# Iteration : 068, Loss on trainig: 1.9614, Accuracy: 0.4688
# Iteration : 069, Loss on trainig: 2.1632, Accuracy: 0.4688
# Iteration : 070, Loss on trainig: 1.7853, Accuracy: 0.5781
# Iteration : 071, Loss on trainig: 1.6369, Accuracy: 0.5000
# Iteration : 072, Loss on trainig: 1.9423, Accuracy: 0.4688
# Iteration : 073, Loss on trainig: 1.9278, Accuracy: 0.4062
# Iteration : 074, Loss on trainig: 2.2820, Accuracy: 0.3438
# Iteration : 075, Loss on trainig: 1.8472, Accuracy: 0.5625
# Iteration : 076, Loss on trainig: 2.0463, Accuracy: 0.3750
# Iteration : 077, Loss on trainig: 2.1543, Accuracy: 0.4844
# Iteration : 078, Loss on trainig: 2.2193, Accuracy: 0.3906
# Iteration : 079, Loss on trainig: 1.9038, Accuracy: 0.5000
# Iteration : 080, Loss on trainig: 2.0876, Accuracy: 0.4375
# Iteration : 081, Loss on trainig: 2.0286, Accuracy: 0.4688
# Iteration : 082, Loss on trainig: 1.8654, Accuracy: 0.4219
# Iteration : 083, Loss on trainig: 2.1305, Accuracy: 0.4688
# Iteration : 084, Loss on trainig: 2.0348, Accuracy: 0.3906
# Iteration : 085, Loss on trainig: 1.8997, Accuracy: 0.5156
# Iteration : 086, Loss on trainig: 1.9505, Accuracy: 0.4844
# Iteration : 087, Loss on trainig: 2.0261, Accuracy: 0.5000
# Iteration : 088, Loss on trainig: 2.2473, Accuracy: 0.4219
# Iteration : 089, Loss on trainig: 2.1604, Accuracy: 0.3750
# Iteration : 090, Loss on trainig: 1.9000, Accuracy: 0.4531
# Iteration : 091, Loss on trainig: 1.9966, Accuracy: 0.3750
# Iteration : 092, Loss on trainig: 2.2270, Accuracy: 0.4219
# Iteration : 093, Loss on trainig: 2.4883, Accuracy: 0.3438
# Iteration : 094, Loss on trainig: 1.8182, Accuracy: 0.5156
# Iteration : 095, Loss on trainig: 1.8320, Accuracy: 0.4844
# Iteration : 096, Loss on trainig: 1.8464, Accuracy: 0.5625
# Iteration : 097, Loss on trainig: 1.7222, Accuracy: 0.5000
# Iteration : 098, Loss on trainig: 2.0343, Accuracy: 0.4688
# Iteration : 099, Loss on trainig: 1.9077, Accuracy: 0.4219
# Iteration : 100, Loss on trainig: 1.8047, Accuracy: 0.4688
# Iteration : 101, Loss on trainig: 1.9917, Accuracy: 0.5469
# Iteration : 102, Loss on trainig: 2.1114, Accuracy: 0.4167
# Epoch: 5/5
# Iteration : 000, Loss on trainig: 1.7937, Accuracy: 0.5156
# Iteration : 001, Loss on trainig: 1.8162, Accuracy: 0.4375
# Iteration : 002, Loss on trainig: 1.9359, Accuracy: 0.4531
# Iteration : 003, Loss on trainig: 1.7200, Accuracy: 0.5312
# Iteration : 004, Loss on trainig: 1.8403, Accuracy: 0.5156
# Iteration : 005, Loss on trainig: 1.6977, Accuracy: 0.5312
# Iteration : 006, Loss on trainig: 1.7838, Accuracy: 0.4375
# Iteration : 007, Loss on trainig: 1.8813, Accuracy: 0.5000
# Iteration : 008, Loss on trainig: 1.9922, Accuracy: 0.4375
# Iteration : 009, Loss on trainig: 1.7773, Accuracy: 0.4688
# Iteration : 010, Loss on trainig: 1.7288, Accuracy: 0.5312
# Iteration : 011, Loss on trainig: 1.7089, Accuracy: 0.4375
# Iteration : 012, Loss on trainig: 2.0826, Accuracy: 0.4062
# Iteration : 013, Loss on trainig: 1.8911, Accuracy: 0.4688
# Iteration : 014, Loss on trainig: 1.9807, Accuracy: 0.4375
# Iteration : 015, Loss on trainig: 1.6827, Accuracy: 0.5469
# Iteration : 016, Loss on trainig: 1.5018, Accuracy: 0.6094
# Iteration : 017, Loss on trainig: 1.9300, Accuracy: 0.4688
# Iteration : 018, Loss on trainig: 2.0812, Accuracy: 0.4531
# Iteration : 019, Loss on trainig: 1.8714, Accuracy: 0.5000
# Iteration : 020, Loss on trainig: 1.8189, Accuracy: 0.4844
# Iteration : 021, Loss on trainig: 1.6654, Accuracy: 0.5469
# Iteration : 022, Loss on trainig: 1.9271, Accuracy: 0.4219
# Iteration : 023, Loss on trainig: 1.7913, Accuracy: 0.5156
# Iteration : 024, Loss on trainig: 1.4954, Accuracy: 0.5469
# Iteration : 025, Loss on trainig: 2.0661, Accuracy: 0.4375
# Iteration : 026, Loss on trainig: 1.3885, Accuracy: 0.6562
# Iteration : 027, Loss on trainig: 1.7138, Accuracy: 0.4844
# Iteration : 028, Loss on trainig: 2.2723, Accuracy: 0.3594
# Iteration : 029, Loss on trainig: 1.6526, Accuracy: 0.5469
# Iteration : 030, Loss on trainig: 1.8399, Accuracy: 0.5625
# Iteration : 031, Loss on trainig: 1.8192, Accuracy: 0.5000
# Iteration : 032, Loss on trainig: 1.7299, Accuracy: 0.5000
# Iteration : 033, Loss on trainig: 2.1595, Accuracy: 0.3906
# Iteration : 034, Loss on trainig: 1.6787, Accuracy: 0.5625
# Iteration : 035, Loss on trainig: 2.1033, Accuracy: 0.4062
# Iteration : 036, Loss on trainig: 1.8856, Accuracy: 0.4688
# Iteration : 037, Loss on trainig: 1.7014, Accuracy: 0.5000
# Iteration : 038, Loss on trainig: 1.7528, Accuracy: 0.4844
# Iteration : 039, Loss on trainig: 2.0247, Accuracy: 0.5156
# Iteration : 040, Loss on trainig: 2.1081, Accuracy: 0.4531
# Iteration : 041, Loss on trainig: 1.6010, Accuracy: 0.5312
# Iteration : 042, Loss on trainig: 2.1084, Accuracy: 0.4062
# Iteration : 043, Loss on trainig: 1.7880, Accuracy: 0.5469
# Iteration : 044, Loss on trainig: 2.1874, Accuracy: 0.3906
# Iteration : 045, Loss on trainig: 1.8053, Accuracy: 0.4375
# Iteration : 046, Loss on trainig: 1.9159, Accuracy: 0.4531
# Iteration : 047, Loss on trainig: 1.9265, Accuracy: 0.5156
# Iteration : 048, Loss on trainig: 2.3560, Accuracy: 0.4219
# Iteration : 049, Loss on trainig: 1.9375, Accuracy: 0.5625
# Iteration : 050, Loss on trainig: 2.3221, Accuracy: 0.3750
# Iteration : 051, Loss on trainig: 1.4602, Accuracy: 0.5312
# Iteration : 052, Loss on trainig: 1.8068, Accuracy: 0.4219
# Iteration : 053, Loss on trainig: 1.8291, Accuracy: 0.4688
# Iteration : 054, Loss on trainig: 1.8972, Accuracy: 0.4062
# Iteration : 055, Loss on trainig: 1.8426, Accuracy: 0.4844
# Iteration : 056, Loss on trainig: 2.0076, Accuracy: 0.4375
# Iteration : 057, Loss on trainig: 1.9989, Accuracy: 0.5625
# Iteration : 058, Loss on trainig: 1.9466, Accuracy: 0.4531
# Iteration : 059, Loss on trainig: 2.1402, Accuracy: 0.4375
# Iteration : 060, Loss on trainig: 1.6094, Accuracy: 0.5625
# Iteration : 061, Loss on trainig: 1.6920, Accuracy: 0.4844
# Iteration : 062, Loss on trainig: 1.9573, Accuracy: 0.5156
# Iteration : 063, Loss on trainig: 1.7919, Accuracy: 0.4375
# Iteration : 064, Loss on trainig: 1.9563, Accuracy: 0.4375
# Iteration : 065, Loss on trainig: 1.8970, Accuracy: 0.4062
# Iteration : 066, Loss on trainig: 2.1405, Accuracy: 0.4531
# Iteration : 067, Loss on trainig: 1.6128, Accuracy: 0.5781
# Iteration : 068, Loss on trainig: 2.0058, Accuracy: 0.4844
# Iteration : 069, Loss on trainig: 2.0147, Accuracy: 0.4375
# Iteration : 070, Loss on trainig: 2.3209, Accuracy: 0.3281
# Iteration : 071, Loss on trainig: 1.9529, Accuracy: 0.4531
# Iteration : 072, Loss on trainig: 1.8447, Accuracy: 0.3906
# Iteration : 073, Loss on trainig: 1.5851, Accuracy: 0.5000
# Iteration : 074, Loss on trainig: 1.8845, Accuracy: 0.4844
# Iteration : 075, Loss on trainig: 1.7547, Accuracy: 0.5000
# Iteration : 076, Loss on trainig: 1.9043, Accuracy: 0.5156
# Iteration : 077, Loss on trainig: 1.7518, Accuracy: 0.4688
# Iteration : 078, Loss on trainig: 1.8851, Accuracy: 0.5781
# Iteration : 079, Loss on trainig: 1.6662, Accuracy: 0.5156
# Iteration : 080, Loss on trainig: 1.7320, Accuracy: 0.5469
# Iteration : 081, Loss on trainig: 1.7567, Accuracy: 0.5156
# Iteration : 082, Loss on trainig: 1.9026, Accuracy: 0.4531
# Iteration : 083, Loss on trainig: 2.3755, Accuracy: 0.3594
# Iteration : 084, Loss on trainig: 2.1610, Accuracy: 0.4844
# Iteration : 085, Loss on trainig: 2.0866, Accuracy: 0.4844
# Iteration : 086, Loss on trainig: 1.4661, Accuracy: 0.5781
# Iteration : 087, Loss on trainig: 1.7136, Accuracy: 0.5000
# Iteration : 088, Loss on trainig: 2.0775, Accuracy: 0.4531
# Iteration : 089, Loss on trainig: 1.7168, Accuracy: 0.4844
# Iteration : 090, Loss on trainig: 2.0465, Accuracy: 0.4688
# Iteration : 091, Loss on trainig: 1.8272, Accuracy: 0.4531
# Iteration : 092, Loss on trainig: 1.9859, Accuracy: 0.4531
# Iteration : 093, Loss on trainig: 1.6272, Accuracy: 0.5000
# Iteration : 094, Loss on trainig: 1.6495, Accuracy: 0.5156
# Iteration : 095, Loss on trainig: 1.9729, Accuracy: 0.4531
# Iteration : 096, Loss on trainig: 1.6934, Accuracy: 0.4844
# Iteration : 097, Loss on trainig: 1.6029, Accuracy: 0.5625
# Iteration : 098, Loss on trainig: 2.1406, Accuracy: 0.4375
# Iteration : 099, Loss on trainig: 2.2445, Accuracy: 0.4062
# Iteration : 100, Loss on trainig: 1.7904, Accuracy: 0.5312
# Iteration : 101, Loss on trainig: 1.8458, Accuracy: 0.5000
# Iteration : 102, Loss on trainig: 1.5319, Accuracy: 0.5417
#  *** Training Ended ***

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
with torch.no_grad():
 
    model.eval()

    for j, (inputs, labels) in enumerate(validationLoader):
        inputs = inputs.to('cuda')
        labels = labels.to('cuda')
 
        # Forward pass - compute outputs on input data using the model
        outputs = model(inputs)
 
        # Compute loss
        loss = criterion(outputs, labels)
 
        # Compute total loss
        validloss += loss.item() * inputs.size(0)
 
        # Calculate  accuracy
        ret, predictions = torch.max(outputs.data, 1)
        correct_counts = predictions.eq(labels.data.view_as(predictions))
 
        # compute the mean
        acc = torch.mean(correct_counts.type(torch.FloatTensor))
 
        # Compute total accuracy 
        validacc += acc.item() * inputs.size(0)
 
        print("Validation number: {:03d}, Validation: Loss: {:.4f}, Accuracy: {:.4f}".format(j, loss.item(), acc.item()))
# Out:
# Validation number: 000, Validation: Loss: 0.6792, Accuracy: 0.7500
# Validation number: 001, Validation: Loss: 0.7915, Accuracy: 0.8750
# Validation number: 002, Validation: Loss: 1.0637, Accuracy: 0.6875
# Validation number: 003, Validation: Loss: 1.3667, Accuracy: 0.7500
# Validation number: 004, Validation: Loss: 0.8603, Accuracy: 0.7500
# Validation number: 005, Validation: Loss: 1.2159, Accuracy: 0.7188
# Validation number: 006, Validation: Loss: 0.7300, Accuracy: 0.7812
# Validation number: 007, Validation: Loss: 1.2578, Accuracy: 0.5938
# Validation number: 008, Validation: Loss: 0.9544, Accuracy: 0.7500
# Validation number: 009, Validation: Loss: 0.9161, Accuracy: 0.6562
# Validation number: 010, Validation: Loss: 1.0628, Accuracy: 0.6562
# Validation number: 011, Validation: Loss: 0.8288, Accuracy: 0.6875
# Validation number: 012, Validation: Loss: 1.2350, Accuracy: 0.5938
# Validation number: 013, Validation: Loss: 0.8099, Accuracy: 0.7500
# Validation number: 014, Validation: Loss: 0.5833, Accuracy: 0.8750
# Validation number: 015, Validation: Loss: 1.2599, Accuracy: 0.6875
# Validation number: 016, Validation: Loss: 1.0408, Accuracy: 0.7812
# Validation number: 017, Validation: Loss: 0.8225, Accuracy: 0.7188
# Validation number: 018, Validation: Loss: 0.7101, Accuracy: 0.8125
# Validation number: 019, Validation: Loss: 0.9874, Accuracy: 0.7500
# Validation number: 020, Validation: Loss: 0.8867, Accuracy: 0.7500
# Validation number: 021, Validation: Loss: 1.1330, Accuracy: 0.6250
# Validation number: 022, Validation: Loss: 0.7541, Accuracy: 0.8125
# Validation number: 023, Validation: Loss: 1.0464, Accuracy: 0.6875
# Validation number: 024, Validation: Loss: 1.1562, Accuracy: 0.6875
# Validation number: 025, Validation: Loss: 1.5470, Accuracy: 0.5556

# %%
correct,total = 0,0
model.eval()
model.to('cuda')
with torch.no_grad():        
    for data in trainLoader:    
        img, lbl = data
        img, lbl = img.to('cuda'), lbl.to('cuda')
        outputs = model(img)
        _, predicted = torch.max(outputs.data, 1)
        total += lbl.size(0)
        correct += (predicted == lbl).sum().item()        
            
print('Accuracy is: %d%%' % (100 * correct / total))
# Out:
# Accuracy is: 68%

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint 
model.class_to_idx = image_datasets['train'].class_to_idx
model.cpu
torch.save ({'structure' :'vgg16',
              'hiddenLayer_1':120,
              'state_dict': model.state_dict(),
              'class_to_idx': model.class_to_idx},
               'checkpoint.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model

def loadCheckpoint(path='checkpoint.pth'):
    checkpoint = torch.load('checkpoint.pth')
    model.cuda()
    for pr in model.parameters():
        pr.requires_grad = False

    structure = checkpoint['structure']
    hiddenLayer_1 = checkpoint['hiddenLayer_1']
    model.class_to_idx = checkpoint['class_to_idx']
    model.state_dict(checkpoint['state_dict'])
    return model


model = loadCheckpoint()
print(model)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (inputs): Linear(in_features=25088, out_features=120, bias=True)
#     (rl1): ReLU()
#     (dropout): Dropout(p=0.5)
#     (hiddenLayer_1): Linear(in_features=120, out_features=90, bias=True)
#     (rl2): ReLU()
#     (hiddenLayer_2): Linear(in_features=90, out_features=70, bias=True)
#     (rl3): ReLU()
#     (hiddenLayer_3): Linear(in_features=70, out_features=102, bias=True)
#     (output): LogSoftmax()
#   )
# )

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    
    # TODO: Process a PIL image for use in a PyTorch model

    proccessedImg = Image.open(image)
   
    prepoceess = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])
    img = prepoceess(proccessedImg)
    
    return img

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    if ax is None:
        fig, ax = plt.subplots()

    image = image.numpy().transpose((1, 2, 0))
    
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax


#try with random image
import random, os
img = random.choice(os.listdir('./flowers/test/7/'))
img_path = './flowers/test/7/' + img


with Image.open(img_path) as image:
    imshow(process_image(img_path))

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, topK=5):
    
    
    with torch.no_grad():
        model.to("cpu")
        image = process_image(image_path)
        image = torch.from_numpy(np.asarray(image).astype('float'))
        image.unsqueeze_(0)
        image = image.float()
  
        outputs = model(image)
        probs, classes = torch.exp(outputs).topk(topK)
        return probs[0].tolist(), classes[0].add(1).tolist()

# %%
img2 = random.choice(os.listdir('./flowers/test/7/'))
img_path2 = './flowers/test/7/' + img2
    
prob, clas = predict(img_path2, model)
print(prob)
print(clas)
flowers = [cat_to_name[str(x)]  for x in clas]
print(flowers)
# Out:
# [0.5236309170722961, 0.44082707166671753, 0.012760636396706104, 0.008889099583029747, 0.00434495136141777]
# [70, 16, 83, 86, 79]
# ['tree poppy', 'globe-flower', 'hibiscus', 'tree mallow', 'toad lily']

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
def display_prediction(img_path2, model):

    # Set up plot
    plt.figure(figsize = (6,10))
    xx = plt.subplot(2,1,1)


    # Make prediction
    probs, clas = predict(img_path2, model) 
    flowers = [cat_to_name[str(a)]  for a in clas]

    # Plot flower
    img = process_image(img_path2)
    imshow(img, xx);

    # Plot bar chart
    plt.subplot(2,1,2)
    sb.barplot(x=probs, y=flowers, color=sb.color_palette()[0]);
    plt.show()
    return None

# %%
display_prediction(img_path2,model)
